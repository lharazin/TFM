# %% [markdown]
# # Bidirectional Neural Network Model - Hiperparameters Tuning
#
# Input: testing different number of months in input using single PCA
#
# Output: optimal max-shape portfolio with tight restrictions for the next period

# %% [markdown]
# ## Data Pre-processing

# %%
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Flatten, GRU, Bidirectional, Input
from keras.regularizers import L2
from keras.optimizers import Adam

from sklearn.model_selection import StratifiedKFold
import keras_tuner

import os
os.chdir(os.path.expanduser('../'))

from helper_functions import (train_and_evaluate_model, calculate_returns_for_model, 
                              daily_to_annual_returns, run_full_backtesting)

# %%
os.chdir(os.path.expanduser('../data'))

from dotenv import load_dotenv
load_dotenv()

from DataProvider import DataProvider

# %%
data_provider = DataProvider()
y = data_provider.get_formatted_targets()
# Out:
# c:\Users\lukas\Documents\Master mAI-X\TFM\venv\Lib\site-packages\cvxpy\problems\problem.py:1403: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# c:\Users\lukas\Documents\Master mAI-X\TFM\venv\Lib\site-packages\cvxpy\problems\problem.py:1403: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# c:\Users\lukas\Documents\Master mAI-X\TFM\venv\Lib\site-packages\cvxpy\problems\problem.py:1403: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(

# %% [markdown]
# ## Cross validation to calculate optimal number of months

# %%
df_countries, _ = data_provider.get_etf_data()
days_to_recalculate = data_provider.get_days_to_recalculate()

val_split = int(0.7 * y.shape[0])
test_split = int(0.8 * y.shape[0])
dates_for_validation = days_to_recalculate[val_split:test_split]

df_prices_val = df_countries[dates_for_validation[0]:]
df_returns_val = np.log(df_prices_val).diff().fillna(0)

# %%
max_sharpe = 0
best_month_no = 0

for no_months in range(3, 10):
    print(f'Bidirectional Model for {no_months} months')
    x = data_provider.get_formatted_features(no_months=no_months)
    x_train, y_train, x_val, y_val, x_test, y_test = data_provider.train_train_split(
        x, y)

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    skf.get_n_splits(x_train, y_train)

    sum_sharpe = 0
    for _, (train_index, val_index) in enumerate(skf.split(x_train, np.zeros(y_train.shape[0]))):
        x_train_fold = x_train[train_index]
        y_train_fold = y_train[train_index]
        x_val_fold = x_train[val_index]
        y_val_fold = y_train[val_index]

        model = Sequential((
            Input(shape=x_train.shape[1:]),
            Bidirectional(layer=GRU(16, return_sequences=True),
                          backward_layer=GRU(16, activation='relu',
                             return_sequences=True,
                             go_backwards=True)),
            Flatten(),
            Dense(16, activation='relu', kernel_regularizer=L2(0.3)),
            Dense(y_train.shape[1], activation='softmax')
        ))
        model.compile(optimizer=Adam(learning_rate=1e-3),
                      loss='mean_squared_error')
        _ = model.fit(x_train_fold, y_train_fold,
                      validation_data=(x_val_fold, y_val_fold),
                      epochs=200, verbose=False)

        total_ret_val, _ = calculate_returns_for_model(
            model, x_val, dates_for_validation, df_returns_val)

        annual_returns = daily_to_annual_returns(total_ret_val)
        annual_volatility = total_ret_val.std()*np.sqrt(252)
        annual_sharpe_val = annual_returns/annual_volatility
        sum_sharpe += annual_sharpe_val
        print('Sharpe fold', annual_sharpe_val)

    mean_sharpe_val = sum_sharpe/5
    print('Mean Sharpe', mean_sharpe_val)
    if mean_sharpe_val > max_sharpe:
        max_sharpe = mean_sharpe_val
        best_month_no = no_months

print('Best number of months', best_month_no,
      'with mean Sharpe ratio', max_sharpe)
# Out:
# Bidirectional Model for 3 months
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Sharpe fold 0.4082487982238115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# Sharpe fold 0.3966729984505027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Sharpe fold 0.4067566394454112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Sharpe fold 0.4220996982336603
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026791C454E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Sharpe fold 0.37240252006080704
# Mean Sharpe 0.40123613088283855
# Bidirectional Model for 4 months
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000266B02AAFC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Sharpe fold 0.3873316517827775
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Sharpe fold 0.38101290595538
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Sharpe fold 0.43813440620306965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Sharpe fold 0.37913698000968266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Sharpe fold 0.37292724392807497
# Mean Sharpe 0.391708637575797
# Bidirectional Model for 5 months
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Sharpe fold 0.3913330066047107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Sharpe fold 0.37610761003320486
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# Sharpe fold 0.41059561577331377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Sharpe fold 0.39319372032146627
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Sharpe fold 0.4425799901333144
# Mean Sharpe 0.402761988573202
# Bidirectional Model for 6 months
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Sharpe fold 0.4171177010699086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Sharpe fold 0.3667646998318625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Sharpe fold 0.37134226911154344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Sharpe fold 0.4144003564058247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Sharpe fold 0.39087028745014846
# Mean Sharpe 0.39209906277385753
# Bidirectional Model for 7 months
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Sharpe fold 0.39215597258447255
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Sharpe fold 0.3789611763564167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Sharpe fold 0.41157522662893864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# Sharpe fold 0.40122636399650186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Sharpe fold 0.4414777435850355
# Mean Sharpe 0.4050792966302731
# Bidirectional Model for 8 months
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# Sharpe fold 0.4082912448478828
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Sharpe fold 0.39135514817199646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Sharpe fold 0.39435699355728787
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Sharpe fold 0.4262665503831833
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Sharpe fold 0.4270267085182845
# Mean Sharpe 0.40945932909572696
# Bidirectional Model for 9 months
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# Sharpe fold 0.4672780162245884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# Sharpe fold 0.4672321894686214
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Sharpe fold 0.3894753821408439
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Sharpe fold 0.4211131039295508
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Sharpe fold 0.45363899765354676
# Mean Sharpe 0.43974753788343024
# Best number of months 9 with mean Sharpe ratio 0.43974753788343024

# %%
best_month_no = 9

x = data_provider.get_formatted_features(no_months=best_month_no)
x_train, y_train, x_val, y_val, x_test, y_test = data_provider.train_train_split(x, y)

# %% [markdown]
# ## Hiperparameters Tuning

# %%
def build_model(hp):
    model = Sequential((
        Input(shape=x_train.shape[1:]),
        Bidirectional(layer=GRU(hp.Choice('gru_units', [16, 32, 64, 128, 256]), 
                                return_sequences=True),
                      backward_layer=GRU(hp.Choice('gru_units', [16, 32, 64, 128, 256]),
                                         activation='relu',
                                         return_sequences=True,
                                         go_backwards=True),
                      input_shape=x_train.shape[1:]),
        Flatten(),
        Dense(hp.Choice('dense_units', [32, 64, 128]),
              activation='relu', kernel_regularizer=L2(hp.Choice('regularizer', [0.1, 0.2, 0.3, 0.4]))),
        Dense(y_train.shape[1], activation='softmax')
    ))
    model.compile(loss='mse')
    return model

# %%
tuner = keras_tuner.RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=100,
    directory='tuning',
    project_name='model_bidirectional')
# Out:
# Reloading Tuner from tuning\model_bidirectional\tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 3
# gru_units (Choice)
# {'default': 16, 'conditions': [], 'values': [16, 32, 64, 128, 256], 'ordered': True}
# dense_units (Choice)
# {'default': 32, 'conditions': [], 'values': [32, 64, 128], 'ordered': True}
# regularizer (Choice)
# {'default': 0.1, 'conditions': [], 'values': [0.1, 0.2, 0.3, 0.4], 'ordered': True}

# %%
tuner.search(x_train, y_train, epochs=150, validation_data=(x_val, y_val))

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in tuning\model_bidirectional
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 029 summary
# Hyperparameters:
# gru_units: 16
# dense_units: 64
# regularizer: 0.1
# Score: 0.0005962718860246241
#
# Trial 055 summary
# Hyperparameters:
# gru_units: 256
# dense_units: 128
# regularizer: 0.1
# Score: 0.0005968974437564611
#
# Trial 010 summary
# Hyperparameters:
# gru_units: 16
# dense_units: 128
# regularizer: 0.1
# Score: 0.0006086834473535419
#
# Trial 017 summary
# Hyperparameters:
# gru_units: 32
# dense_units: 128
# regularizer: 0.1
# Score: 0.000613053678534925
#
# Trial 009 summary
# Hyperparameters:
# gru_units: 64
# dense_units: 64
# regularizer: 0.2
# Score: 0.0006181540084071457
#
# Trial 036 summary
# Hyperparameters:
# gru_units: 64
# dense_units: 128
# regularizer: 0.1
# Score: 0.0006190626882016659
#
# Trial 041 summary
# Hyperparameters:
# gru_units: 128
# dense_units: 128
# regularizer: 0.1
# Score: 0.0006311071338132024
#
# Trial 005 summary
# Hyperparameters:
# gru_units: 32
# dense_units: 64
# regularizer: 0.1
# Score: 0.0006328786839731038
#
# Trial 050 summary
# Hyperparameters:
# gru_units: 128
# dense_units: 64
# regularizer: 0.1
# Score: 0.0006330061005428433
#
# Trial 035 summary
# Hyperparameters:
# gru_units: 128
# dense_units: 128
# regularizer: 0.2
# Score: 0.0006398583645932376

# %% [markdown]
# ## Best Model training

# %%
# best_model = tuner.get_best_models()[0]

best_model = Sequential((
    Input(shape=x_train.shape[1:]),
    Bidirectional(layer=GRU(16, return_sequences=True),
                    backward_layer=GRU(16, activation='relu',
                        return_sequences=True,
                        go_backwards=True)),
    Flatten(),
    Dense(64, activation='relu', kernel_regularizer=L2(0.1)),
    Dense(y_train.shape[1], activation='softmax')
))

train_and_evaluate_model(best_model, x_train, y_train,
                         x_val, y_val, x_test, y_test)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 9, 32)          │         4,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 288)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 27)             │         1,755 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,571 (95.98 KB)
#  Trainable params: 24,571 (95.98 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 10.0575 - val_loss: 8.8655 - learning_rate: 0.0010
# Epoch 2/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5127 - val_loss: 7.4628 - learning_rate: 0.0010
# Epoch 3/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1547 - val_loss: 6.2428 - learning_rate: 0.0010
# Epoch 4/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9770 - val_loss: 5.1939 - learning_rate: 0.0010
# Epoch 5/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9664 - val_loss: 4.3001 - learning_rate: 0.0010
# Epoch 6/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1067 - val_loss: 3.5440 - learning_rate: 0.0010
# Epoch 7/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3809 - val_loss: 2.9083 - learning_rate: 0.0010
# Epoch 8/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7713 - val_loss: 2.3763 - learning_rate: 0.0010
# Epoch 9/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2626 - val_loss: 1.9342 - learning_rate: 0.0010
# Epoch 10/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8398 - val_loss: 1.5679 - learning_rate: 0.0010
# Epoch 11/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4898 - val_loss: 1.2655 - learning_rate: 0.0010
# Epoch 12/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2012 - val_loss: 1.0169 - learning_rate: 0.0010
# Epoch 13/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9643 - val_loss: 0.8135 - learning_rate: 0.0010
# Epoch 14/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7706 - val_loss: 0.6480 - learning_rate: 0.0010
# Epoch 15/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6130 - val_loss: 0.5136 - learning_rate: 0.0010
# Epoch 16/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4852 - val_loss: 0.4050 - learning_rate: 0.0010
# Epoch 17/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3823 - val_loss: 0.3180 - learning_rate: 0.0010
# Epoch 18/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2998 - val_loss: 0.2485 - learning_rate: 0.0010
# Epoch 19/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2339 - val_loss: 0.1931 - learning_rate: 0.0010
# Epoch 20/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1816 - val_loss: 0.1495 - learning_rate: 0.0010
# Epoch 21/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1403 - val_loss: 0.1151 - learning_rate: 0.0010
# Epoch 22/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1078 - val_loss: 0.0882 - learning_rate: 0.0010
# Epoch 23/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0824 - val_loss: 0.0670 - learning_rate: 0.0010
# Epoch 24/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0628 - val_loss: 0.0510 - learning_rate: 0.0010
# Epoch 25/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0476 - val_loss: 0.0387 - learning_rate: 0.0010
# Epoch 26/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0359 - val_loss: 0.0291 - learning_rate: 0.0010
# Epoch 27/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0270 - val_loss: 0.0219 - learning_rate: 0.0010
# Epoch 28/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0202 - val_loss: 0.0163 - learning_rate: 0.0010
# Epoch 29/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0150 - val_loss: 0.0122 - learning_rate: 0.0010
# Epoch 30/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0113 - val_loss: 0.0090 - learning_rate: 0.0010
# Epoch 31/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0085 - val_loss: 0.0068 - learning_rate: 0.0010
# Epoch 32/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 33/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - val_loss: 0.0045 - learning_rate: 0.0010
# Epoch 34/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037 - val_loss: 0.0030 - learning_rate: 0.0010
# Epoch 35/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 36/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0020 - val_loss: 0.0022 - learning_rate: 0.0010
# Epoch 37/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 38/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 39/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - val_loss: 9.9928e-04 - learning_rate: 0.0010
# Epoch 40/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4997e-04 - val_loss: 9.5082e-04 - learning_rate: 0.0010
# Epoch 41/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0643e-04 - val_loss: 9.0315e-04 - learning_rate: 0.0010
# Epoch 42/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0742e-04 - val_loss: 8.2217e-04 - learning_rate: 0.0010
# Epoch 43/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5845e-04 - val_loss: 8.9938e-04 - learning_rate: 0.0010
# Epoch 44/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3035e-04 - val_loss: 6.8774e-04 - learning_rate: 0.0010
# Epoch 45/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2232e-04 - val_loss: 6.3479e-04 - learning_rate: 0.0010
# Epoch 46/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2279e-04 - val_loss: 6.4748e-04 - learning_rate: 0.0010
# Epoch 47/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4159e-04 - val_loss: 8.8441e-04 - learning_rate: 0.0010
# Epoch 48/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2104e-04 - val_loss: 8.1223e-04 - learning_rate: 0.0010
# Epoch 49/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7751e-04 - val_loss: 7.2532e-04 - learning_rate: 0.0010
# Epoch 50/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3597e-04 - val_loss: 7.4474e-04 - learning_rate: 0.0010
# Epoch 51/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3510e-04 - val_loss: 6.2580e-04 - learning_rate: 0.0010
# Epoch 52/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5582e-04 - val_loss: 6.3124e-04 - learning_rate: 0.0010
# Epoch 53/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2852e-04 - val_loss: 5.9583e-04 - learning_rate: 0.0010
# Epoch 54/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7165e-04 - val_loss: 6.0872e-04 - learning_rate: 0.0010
# Epoch 55/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6586e-04 - val_loss: 5.9988e-04 - learning_rate: 0.0010
# Epoch 56/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9451e-04 - val_loss: 6.0967e-04 - learning_rate: 0.0010
# Epoch 57/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3865e-04 - val_loss: 6.8044e-04 - learning_rate: 0.0010
# Epoch 58/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9406e-04 - val_loss: 5.8778e-04 - learning_rate: 0.0010
# Epoch 59/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2599e-04 - val_loss: 6.5841e-04 - learning_rate: 0.0010
# Epoch 60/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1621e-04 - val_loss: 7.5281e-04 - learning_rate: 0.0010
# Epoch 61/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5694e-04 - val_loss: 6.4839e-04 - learning_rate: 0.0010
# Epoch 62/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1700e-04 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 63/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8209e-04 - val_loss: 6.0761e-04 - learning_rate: 0.0010
# Epoch 64/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3885e-04 - val_loss: 6.3324e-04 - learning_rate: 0.0010
# Epoch 65/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9979e-04 - val_loss: 6.2959e-04 - learning_rate: 0.0010
# Epoch 66/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4137e-04 - val_loss: 9.1967e-04 - learning_rate: 0.0010
# Epoch 67/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5846e-04 - val_loss: 5.9605e-04 - learning_rate: 0.0010
# Epoch 68/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2165e-04 - val_loss: 5.9441e-04 - learning_rate: 0.0010
# Epoch 69/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9458e-04 - val_loss: 6.1221e-04 - learning_rate: 0.0010
# Epoch 70/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1824e-04 - val_loss: 8.8166e-04 - learning_rate: 0.0010
# Epoch 71/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8307e-04 - val_loss: 7.6188e-04 - learning_rate: 0.0010
# Epoch 72/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2841e-04 - val_loss: 6.0029e-04 - learning_rate: 0.0010
# Epoch 73/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8617e-04 - val_loss: 6.0014e-04 - learning_rate: 0.0010
# Epoch 74/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3282e-04 - val_loss: 7.7109e-04 - learning_rate: 0.0010
# Epoch 75/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0317e-04 - val_loss: 5.9040e-04 - learning_rate: 0.0010
# Epoch 76/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9494e-04 - val_loss: 7.7221e-04 - learning_rate: 0.0010
# Epoch 77/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4515e-04 - val_loss: 6.0667e-04 - learning_rate: 0.0010
# Epoch 78/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8053e-04 - val_loss: 6.0288e-04 - learning_rate: 0.0010
# Epoch 79/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2416e-04 - val_loss: 8.8477e-04 - learning_rate: 0.0010
# Epoch 80/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8587e-04 - val_loss: 5.8998e-04 - learning_rate: 0.0010
# Epoch 81/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8900e-04 - val_loss: 5.8018e-04 - learning_rate: 0.0010
# Epoch 82/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7024e-04 - val_loss: 6.7396e-04 - learning_rate: 0.0010
# Epoch 83/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4081e-04 - val_loss: 5.9694e-04 - learning_rate: 0.0010
# Epoch 84/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4203e-04 - val_loss: 5.9010e-04 - learning_rate: 0.0010
# Epoch 85/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3920e-04 - val_loss: 5.6552e-04 - learning_rate: 0.0010
# Epoch 86/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7784e-04 - val_loss: 6.0929e-04 - learning_rate: 0.0010
# Epoch 87/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8120e-04 - val_loss: 5.8951e-04 - learning_rate: 0.0010
# Epoch 88/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7464e-04 - val_loss: 6.1821e-04 - learning_rate: 0.0010
# Epoch 89/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2616e-04 - val_loss: 6.0653e-04 - learning_rate: 0.0010
# Epoch 90/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4064e-04 - val_loss: 5.9754e-04 - learning_rate: 0.0010
# Epoch 91/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3922e-04 - val_loss: 6.9901e-04 - learning_rate: 0.0010
# Epoch 92/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0150e-04 - val_loss: 6.7997e-04 - learning_rate: 0.0010
# Epoch 93/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6667e-04 - val_loss: 5.7328e-04 - learning_rate: 0.0010
# Epoch 94/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7342e-04 - val_loss: 6.1284e-04 - learning_rate: 0.0010
# Epoch 95/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8909e-04 - val_loss: 6.5864e-04 - learning_rate: 0.0010
# Epoch 96/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9017e-04 - val_loss: 5.6998e-04 - learning_rate: 0.0010
# Epoch 97/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9560e-04 - val_loss: 5.6897e-04 - learning_rate: 0.0010
# Epoch 98/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6218e-04 - val_loss: 6.5120e-04 - learning_rate: 0.0010
# Epoch 99/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9634e-04 - val_loss: 5.7278e-04 - learning_rate: 0.0010
# Epoch 100/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7732e-04 - val_loss: 5.7085e-04 - learning_rate: 0.0010
# Epoch 101/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5863e-04 - val_loss: 5.8744e-04 - learning_rate: 0.0010
# Epoch 102/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6457e-04 - val_loss: 6.0957e-04 - learning_rate: 0.0010
# Epoch 103/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6768e-04 - val_loss: 6.2985e-04 - learning_rate: 0.0010
# Epoch 104/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7433e-04 - val_loss: 5.9987e-04 - learning_rate: 0.0010
# Epoch 105/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8893e-04 - val_loss: 5.9369e-04 - learning_rate: 0.0010
# Epoch 106/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5214e-04 - val_loss: 6.0930e-04 - learning_rate: 0.0010
# Epoch 107/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2988e-04 - val_loss: 6.1382e-04 - learning_rate: 0.0010
# Epoch 108/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3431e-04 - val_loss: 5.6564e-04 - learning_rate: 0.0010
# Epoch 109/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8685e-04 - val_loss: 6.2500e-04 - learning_rate: 0.0010
# Epoch 110/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5654e-04 - val_loss: 6.6236e-04 - learning_rate: 0.0010
# Epoch 111/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9881e-04 - val_loss: 6.4210e-04 - learning_rate: 0.0010
# Epoch 112/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7818e-04 - val_loss: 7.1386e-04 - learning_rate: 0.0010
# Epoch 113/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8615e-04 - val_loss: 7.4923e-04 - learning_rate: 0.0010
# Epoch 114/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8544e-04 - val_loss: 5.8512e-04 - learning_rate: 0.0010
# Epoch 115/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8020e-04 - val_loss: 6.2971e-04 - learning_rate: 0.0010
# Epoch 116/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1107e-04 - val_loss: 6.2552e-04 - learning_rate: 0.0010
# Epoch 117/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9126e-04 - val_loss: 6.6735e-04 - learning_rate: 0.0010
# Epoch 118/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6560e-04 - val_loss: 5.6462e-04 - learning_rate: 0.0010
# Epoch 119/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5247e-04 - val_loss: 5.8919e-04 - learning_rate: 0.0010
# Epoch 120/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9990e-04 - val_loss: 5.9922e-04 - learning_rate: 0.0010
# Epoch 121/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5630e-04 - val_loss: 5.8875e-04 - learning_rate: 0.0010
# Epoch 122/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5359e-04 - val_loss: 5.9166e-04 - learning_rate: 0.0010
# Epoch 123/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6898e-04 - val_loss: 6.7492e-04 - learning_rate: 0.0010
# Epoch 124/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8139e-04 - val_loss: 5.7260e-04 - learning_rate: 0.0010
# Epoch 125/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8215e-04 - val_loss: 8.4448e-04 - learning_rate: 0.0010
# Epoch 126/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9313e-04 - val_loss: 5.7275e-04 - learning_rate: 0.0010
# Epoch 127/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6203e-04 - val_loss: 5.8422e-04 - learning_rate: 0.0010
# Epoch 128/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7049e-04 - val_loss: 5.6427e-04 - learning_rate: 0.0010
# Epoch 129/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6110e-04 - val_loss: 6.8151e-04 - learning_rate: 0.0010
# Epoch 130/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4287e-04 - val_loss: 6.4878e-04 - learning_rate: 0.0010
# Epoch 131/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7574e-04 - val_loss: 7.0090e-04 - learning_rate: 0.0010
# Epoch 132/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5837e-04 - val_loss: 6.1078e-04 - learning_rate: 1.0000e-04
# Epoch 133/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3745e-04 - val_loss: 5.6386e-04 - learning_rate: 1.0000e-04
# Epoch 134/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3111e-04 - val_loss: 5.6295e-04 - learning_rate: 1.0000e-04
# Epoch 135/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2591e-04 - val_loss: 5.8092e-04 - learning_rate: 1.0000e-04
# Epoch 136/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3992e-04 - val_loss: 5.7915e-04 - learning_rate: 1.0000e-04
# Epoch 137/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3222e-04 - val_loss: 5.6446e-04 - learning_rate: 1.0000e-04
# Epoch 138/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4053e-04 - val_loss: 5.5955e-04 - learning_rate: 1.0000e-04
# Epoch 139/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2034e-04 - val_loss: 5.6674e-04 - learning_rate: 1.0000e-04
# Epoch 140/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2113e-04 - val_loss: 5.7523e-04 - learning_rate: 1.0000e-04
# Epoch 141/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2914e-04 - val_loss: 5.7003e-04 - learning_rate: 1.0000e-04
# Epoch 142/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2178e-04 - val_loss: 5.6558e-04 - learning_rate: 1.0000e-04
# Epoch 143/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3543e-04 - val_loss: 5.5792e-04 - learning_rate: 1.0000e-04
# Epoch 144/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2834e-04 - val_loss: 5.6211e-04 - learning_rate: 1.0000e-04
# Epoch 145/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2542e-04 - val_loss: 5.6302e-04 - learning_rate: 1.0000e-04
# Epoch 146/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2653e-04 - val_loss: 5.7024e-04 - learning_rate: 1.0000e-04
# Epoch 147/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0996e-04 - val_loss: 5.7517e-04 - learning_rate: 1.0000e-04
# Epoch 148/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3813e-04 - val_loss: 5.6448e-04 - learning_rate: 1.0000e-04
# Epoch 149/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3153e-04 - val_loss: 5.6237e-04 - learning_rate: 1.0000e-04
# Epoch 150/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1692e-04 - val_loss: 5.6853e-04 - learning_rate: 1.0000e-04
# Epoch 151/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4067e-04 - val_loss: 5.6150e-04 - learning_rate: 1.0000e-04
# Epoch 152/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2660e-04 - val_loss: 5.5903e-04 - learning_rate: 1.0000e-04
# Epoch 153/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4055e-04 - val_loss: 5.5976e-04 - learning_rate: 1.0000e-04
# Epoch 154/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2764e-04 - val_loss: 5.8111e-04 - learning_rate: 1.0000e-04
# Epoch 155/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2289e-04 - val_loss: 5.5707e-04 - learning_rate: 1.0000e-04
# Epoch 156/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3755e-04 - val_loss: 5.5535e-04 - learning_rate: 1.0000e-04
# Epoch 157/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4003e-04 - val_loss: 5.5819e-04 - learning_rate: 1.0000e-04
# Epoch 158/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3334e-04 - val_loss: 5.7457e-04 - learning_rate: 1.0000e-04
# Epoch 159/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2205e-04 - val_loss: 5.6633e-04 - learning_rate: 1.0000e-04
# Epoch 160/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2809e-04 - val_loss: 5.5550e-04 - learning_rate: 1.0000e-04
# Epoch 161/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3731e-04 - val_loss: 5.6052e-04 - learning_rate: 1.0000e-04
# Epoch 162/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3019e-04 - val_loss: 5.6536e-04 - learning_rate: 1.0000e-04
# Epoch 163/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2292e-04 - val_loss: 5.5754e-04 - learning_rate: 1.0000e-04
# Epoch 164/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3494e-04 - val_loss: 5.5850e-04 - learning_rate: 1.0000e-04
# Epoch 165/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2839e-04 - val_loss: 5.6533e-04 - learning_rate: 1.0000e-04
# Epoch 166/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1350e-04 - val_loss: 5.5914e-04 - learning_rate: 1.0000e-04
# Epoch 167/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2122e-04 - val_loss: 5.6505e-04 - learning_rate: 1.0000e-04
# Epoch 168/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0300e-04 - val_loss: 5.5860e-04 - learning_rate: 1.0000e-04
# Epoch 169/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2265e-04 - val_loss: 5.6213e-04 - learning_rate: 1.0000e-04
# Epoch 170/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1175e-04 - val_loss: 5.9115e-04 - learning_rate: 1.0000e-04
# Epoch 171/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2954e-04 - val_loss: 5.6021e-04 - learning_rate: 1.0000e-04
# Epoch 172/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4008e-04 - val_loss: 5.5821e-04 - learning_rate: 1.0000e-04
# Epoch 173/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2158e-04 - val_loss: 5.7124e-04 - learning_rate: 1.0000e-04
# Epoch 174/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1059e-04 - val_loss: 5.7548e-04 - learning_rate: 1.0000e-04
# Epoch 175/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1383e-04 - val_loss: 5.5544e-04 - learning_rate: 1.0000e-04
# Epoch 176/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1970e-04 - val_loss: 5.5348e-04 - learning_rate: 1.0000e-04
# Epoch 177/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2005e-04 - val_loss: 5.5806e-04 - learning_rate: 1.0000e-04
# Epoch 178/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2489e-04 - val_loss: 5.6524e-04 - learning_rate: 1.0000e-04
# Epoch 179/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2388e-04 - val_loss: 5.5417e-04 - learning_rate: 1.0000e-04
# Epoch 180/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2627e-04 - val_loss: 5.5318e-04 - learning_rate: 1.0000e-04
# Epoch 181/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2204e-04 - val_loss: 5.6449e-04 - learning_rate: 1.0000e-04
# Epoch 182/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0546e-04 - val_loss: 5.6529e-04 - learning_rate: 1.0000e-05
# Epoch 183/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3804e-04 - val_loss: 5.6470e-04 - learning_rate: 1.0000e-05
# Epoch 184/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2318e-04 - val_loss: 5.6327e-04 - learning_rate: 1.0000e-05
# Epoch 185/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3456e-04 - val_loss: 5.6052e-04 - learning_rate: 1.0000e-05
# Epoch 186/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3761e-04 - val_loss: 5.5924e-04 - learning_rate: 1.0000e-05
# Epoch 187/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1761e-04 - val_loss: 5.5771e-04 - learning_rate: 1.0000e-05
# Epoch 188/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3036e-04 - val_loss: 5.5730e-04 - learning_rate: 1.0000e-05
# Epoch 189/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3230e-04 - val_loss: 5.5680e-04 - learning_rate: 1.0000e-05
# Epoch 190/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2228e-04 - val_loss: 5.5780e-04 - learning_rate: 1.0000e-05
# Epoch 191/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2531e-04 - val_loss: 5.5901e-04 - learning_rate: 1.0000e-05
# Epoch 192/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2932e-04 - val_loss: 5.5802e-04 - learning_rate: 1.0000e-05
# Epoch 193/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1744e-04 - val_loss: 5.5803e-04 - learning_rate: 1.0000e-05
# Epoch 194/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3473e-04 - val_loss: 5.5780e-04 - learning_rate: 1.0000e-05
# Epoch 195/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2227e-04 - val_loss: 5.5756e-04 - learning_rate: 1.0000e-05
# Epoch 196/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3323e-04 - val_loss: 5.5714e-04 - learning_rate: 1.0000e-05
# Epoch 197/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2153e-04 - val_loss: 5.5571e-04 - learning_rate: 1.0000e-05
# Epoch 198/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3721e-04 - val_loss: 5.5559e-04 - learning_rate: 1.0000e-05
# Epoch 199/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0185e-04 - val_loss: 5.5602e-04 - learning_rate: 1.0000e-05
# Epoch 200/200
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0586e-04 - val_loss: 5.5623e-04 - learning_rate: 1.0000e-05
# Train error: 0.0004341075546108186
# Val error: 0.0005562331061810255
# Test error: 0.0010707586770877242
# Execution time 13.04 seconds

# %% [markdown]
# ## Backtesting

# %%
models = {'Tuned Model Bidirectional': (best_model, x_test)}
df_results = run_full_backtesting(data_provider, models)
df_results
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
#                           Annual Returns Annual Volatility Sharpe Ratio  \
# Benchmark                       0.076754          0.203326     0.377494
# Tuned Model Bidirectional       0.060433          0.201665     0.299669
#
#                           Sortino Ratio Max Drawdown Max Time Under Water  \
# Benchmark                      0.442047    -0.354829                500.0
# Tuned Model Bidirectional      0.347459    -0.367529                493.0
#
#                           Calmar Ratio Information Ratio
# Benchmark                     0.216313                 0
# Tuned Model Bidirectional      0.16443         -0.583788
