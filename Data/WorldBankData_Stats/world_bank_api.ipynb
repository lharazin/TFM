# %% [markdown]
# # World Bank Data - API

# %% [markdown]
# Using third party library: https://pypi.org/project/wbgapi/

# %%
import pandas as pd
import wbgapi as wb

from dotenv import load_dotenv
load_dotenv()

import os
os.chdir(os.path.expanduser('../AWS_Lambdas/src/lambda_world_bank_download/'))
from WorldBankApiHandler import WorldBankApiHandler

# %%
api_handler = WorldBankApiHandler()
api_handler.read_world_bank_indicator('SP.POP.TOTL', 24)
# Out:
#             United Arab Emirates   Argentina   Australia    Austria  \
# 1999-01-01             3097563.0  36653031.0  18812264.0  7992324.0
# 2000-01-01             3275333.0  37070774.0  19028802.0  8011566.0
# 2001-01-01             3454198.0  37480493.0  19274701.0  8042293.0
# 2002-01-01             3633655.0  37885028.0  19495210.0  8081957.0
# 2003-01-01             3813443.0  38278164.0  19720737.0  8121423.0
# 2004-01-01             3993339.0  38668796.0  19932722.0  8171966.0
# 2005-01-01             4280993.0  39070501.0  20176844.0  8227829.0
# 2006-01-01             4898954.0  39476851.0  20450966.0  8268641.0
# 2007-01-01             5872624.0  39876111.0  20827622.0  8295487.0
# 2008-01-01             6988685.0  40273769.0  21249199.0  8321496.0
# 2009-01-01             7992644.0  40684338.0  21691653.0  8343323.0
# 2010-01-01             8481771.0  40788453.0  22031750.0  8363404.0
# 2011-01-01             8575205.0  41261490.0  22340024.0  8391643.0
# ...

# %%
api_handler.update_world_bank_indicators(2)
# Out:
# 11 indicators read
# Stock Market Cap (id=41): inserted 74 records from 2019 to 2020
# Stock Market Cap Pct of GDP (id=42): inserted 74 records from 2019 to 2020
# Listed Domestic Companies Total (id=43): inserted 72 records from 2019 to 2020
# Stocks Traded Total Value (id=44): inserted 72 records from 2019 to 2020
# Stocks Traded Total Value Pct of GDP (id=45): inserted 72 records from 2019 to 2020
# GDP (id=46): inserted 98 records from 2021 to 2022
# GDP Per Capita (id=47): inserted 98 records from 2021 to 2022
# Population (id=48): inserted 98 records from 2021 to 2022
# Current Account Pct of GDP (id=49): inserted 94 records from 2021 to 2022
# Current Account (id=50): inserted 96 records from 2021 to 2022
# Government Expense (id=51): inserted 50 records from 2021 to 2022
