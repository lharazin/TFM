# %%
import pandas as pd
import numpy as np
from oecd_api import *

# %% [markdown]
# ## GDP Annual Growth Rate (YoY)

# %%
# gdp_df = pd.read_csv('Indicators/OECD_Quaterly GDP YoY.csv', parse_dates=True, index_col=0)
# gdp_df = gdp_df.round(2)
# gdp_df.to_csv('KeyIndicators/gdp_annual_growth_rate.csv')

# %%
# gdp_df.index = pd.date_range(start='1999-01-01', end='2023-07-01', freq='QS')
# gdp_df.to_csv('KeyIndicators/gdp_annual_growth_rate.csv')

# %%
gdp_df = pd.read_csv('KeyIndicators/gdp_annual_growth_rate.csv', parse_dates=True, index_col=0)
gdp_df
# Out:
#             United States  Japan  United Kingdom  Canada  France  Switzerland  \
# 1999-01-01           4.82  -0.84            2.34    4.19    2.78         1.03
# 1999-04-01           4.72  -0.03            2.17    5.01    2.61         0.58
# 1999-07-01           4.79   0.33            3.47    5.69    3.54         1.17
# 1999-10-01           4.82  -0.44            4.26    5.74    4.18         3.73
# 2000-01-01           4.22   2.67            4.82    5.52    4.36         4.32
# ...                   ...    ...             ...     ...     ...          ...
# 2022-07-01           1.71   1.51            2.06    3.99    1.32         1.40
# 2022-10-01           0.65   0.63            0.66    2.15    0.78         1.14
# 2023-01-01           1.72   2.48            0.46    1.80    0.95         1.51
# 2023-04-01           2.38   2.27            0.56    1.19    1.17         0.40
# 2023-07-01           3.00   1.63            0.61    0.46    0.56         0.43
#
# ...

# %%
check_data_coverage(gdp_df)
# Out:
# Data coverage since 1999 (50 countries):  59.3 %
# Data coverage since 2013 (30 countries): 99.9 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'France',
#        'Switzerland', 'Germany', 'Australia', 'Netherlands', 'Sweden', 'Spain',
#        'Italy', 'Belgium', 'Norway', 'Israel', 'Ireland', 'Austria', 'China',
#        'Taiwan', 'India', 'Korea', 'Brazil', 'Saudi Arabia', 'South Africa',
#        'Mexico', 'Indonesia', 'Turkiye', 'Poland', 'Argentina', 'Russia'],
#       dtype='object')
#
# No data:
# Index([], dtype='object')
#
# Missing first:
#
# Missing last:
#
# Done

# %% [markdown]
# ## GDP Growth Rate (QoQ)

# %%
# gdp_df = pd.read_csv('Indicators/OECD_Quaterly GDP QoQ.csv', parse_dates=True, index_col=0)
# gdp_df['Taiwan'] = np.nan
# gdp_df = gdp_df[selected_countries].round(2)
# gdp_df.to_csv('KeyIndicators/gdp_growth_rate.csv')
# gdp_df

# %%
gdp_growth_qoq = pd.read_csv('KeyIndicators/gdp_growth_rate.csv', parse_dates=True, index_col=0)
gdp_growth_qoq
# Out:
#             United States  Japan  United Kingdom  Canada  France  Switzerland  \
# 1999-01-01           0.94  -1.37            0.69    1.81    0.66         0.10
# 1999-04-01           0.83   0.38            0.47    0.84    0.62         0.65
# 1999-07-01           1.33   0.53            1.60    1.56    1.50         0.63
# 1999-10-01           1.64   0.03            1.43    1.41    1.34         2.32
# 2000-01-01           0.36   1.71            1.23    1.60    0.83         0.66
# ...                   ...    ...             ...     ...     ...          ...
# 2022-07-01           0.66  -0.10           -0.09    0.46    0.50         0.25
# 2022-10-01           0.64   0.25            0.13   -0.22    0.00        -0.03
# 2023-01-01           0.56   1.23            0.32    0.61    0.06         0.31
# 2023-04-01           0.51   0.88            0.19    0.34    0.61        -0.13
# 2023-07-01           1.26  -0.73           -0.03   -0.27   -0.11         0.27
#
# ...

# %%
check_data_coverage(gdp_growth_qoq)
# Out:
# Data coverage since 1999 (50 countries):  57.9 %
# Data coverage since 2013 (30 countries): 99.3 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'France',
#        'Switzerland', 'Germany', 'Australia', 'Netherlands', 'Sweden', 'Spain',
#        'Italy', 'Belgium', 'Norway', 'Israel', 'Ireland', 'Austria', 'China',
#        'Taiwan', 'India', 'Korea', 'Brazil', 'Saudi Arabia', 'South Africa',
#        'Mexico', 'Indonesia', 'Turkiye', 'Poland', 'Argentina', 'Russia'],
#       dtype='object')
#
# No data:
# Index([], dtype='object')
#
# Missing first:
# China 2011-01-01 00:00:00
# Saudi Arabia 2010-04-01 00:00:00
#
# Missing last:
# Russia 2021-07-01 00:00:00
#
# Done

# %% [markdown]
# ## Monthly Unemployment Rate

# %%
# monthly_unemployment = pd.read_csv('Indicators/OECD_Monthly Unemployment.csv', parse_dates=True, index_col=0)
# monthly_unemployment['Taiwan'] = np.nan
# monthly_unemployment = monthly_unemployment[selected_countries].round(2)
# monthly_unemployment.to_csv('KeyIndicators/monthly_unemployment.csv')

# %%
# Source file '../OECD_Monthly Unemployment.csv' and '../OECD_Quarterly Unemployment.csv'
monthly_unemployment = pd.read_csv('KeyIndicators/monthly_unemployment.csv', parse_dates=True, index_col=0)
monthly_unemployment
# Out:
#             United States  Japan  United Kingdom  Canada  France  Switzerland  \
# 1999-01-01            4.3    4.5             6.2     7.9    12.0          3.5
# 1999-02-01            4.4    4.6             6.2     7.9    12.0          3.4
# 1999-03-01            4.2    4.7             6.2     7.9    11.8          3.2
# 1999-04-01            4.3    4.7             6.1     8.2    11.7          2.9
# 1999-05-01            4.2    4.7             6.0     7.9    11.5          2.7
# ...                   ...    ...             ...     ...     ...          ...
# 2023-06-01            3.6    2.5             4.3     5.4     7.3          1.9
# 2023-07-01            3.5    2.7             NaN     5.5     7.4          1.9
# 2023-08-01            3.8    2.7             NaN     5.5     7.4          2.0
# 2023-09-01            3.8    2.6             4.2     5.5     7.3          2.0
# 2023-10-01            3.9    2.5             NaN     5.7     7.3          2.0
#
# ...

# %%
check_data_coverage(monthly_unemployment)
# Out:
# Data coverage since 1999 (50 countries):  50.2 %
# Data coverage since 2013 (30 countries): 88.1 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'France',
#        'Switzerland', 'Germany', 'Australia', 'Netherlands', 'Sweden', 'Spain',
#        'Italy', 'Belgium', 'Norway', 'Israel', 'Ireland', 'Austria', 'China',
#        'Taiwan', 'India', 'Korea', 'Brazil', 'Saudi Arabia', 'South Africa',
#        'Mexico', 'Indonesia', 'Turkiye', 'Poland', 'Argentina', 'Russia'],
#       dtype='object')
#
# No data:
# Index([], dtype='object')
#
# Missing first:
# China 2002-07-01 00:00:00
# India 2018-11-01 00:00:00
# Brazil 2012-03-01 00:00:00
# Saudi Arabia 2000-01-01 00:00:00
# South Africa 2000-07-01 00:00:00
# Indonesia 2000-01-01 00:00:00
# Turkiye 2005-01-01 00:00:00
# Argentina 2002-10-01 00:00:00
#
# Missing last:
#
# Done

# %% [markdown]
# ## Inflation Rate

# %%
# inflation_rate = pd.read_csv('Indicators/OECD_Inflation Rate.csv', parse_dates=True, index_col=0)
# inflation_rate['Taiwan'] = np.nan
# inflation_rate = inflation_rate[selected_countries].round(2)
# inflation_rate.to_csv('KeyIndicators/inflation_rate.csv')
# inflation_rate

# %%
# Source file '../OECD_Inflation Rate.csv' and '../OECD_Inflation Rate Q.csv'
inflation_rate = pd.read_csv('KeyIndicators/inflation_rate.csv', parse_dates=True, index_col=0)
inflation_rate
# Out:
#             United States  Japan  United Kingdom  Canada  France  Switzerland  \
# 1999-01-01           1.67    0.2             2.0    0.66    0.24         0.07
# 1999-02-01           1.61   -0.1             1.9    0.66    0.18         0.29
# 1999-03-01           1.73   -0.4             2.1    0.99    0.35         0.47
# 1999-04-01           2.28   -0.1             2.0    1.65    0.42         0.59
# 1999-05-01           2.09   -0.4             1.7    1.53    0.41         0.58
# ...                   ...    ...             ...     ...     ...          ...
# 2023-06-01           2.97    3.3             7.3    2.81    4.53         1.71
# 2023-07-01           3.18    3.3             6.4    3.27    4.29         1.61
# 2023-08-01           3.67    3.2             6.3    4.00    4.86         1.55
# 2023-09-01           3.70    3.0             6.3    3.80    4.90         1.65
# 2023-10-01           3.24    3.3             4.7    3.12    3.98         1.69
#
# ...

# %%
check_data_coverage(inflation_rate)
# Out:
# Data coverage since 1999 (50 countries):  58.5 %
# Data coverage since 2013 (30 countries): 97.2 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'France',
#        'Switzerland', 'Germany', 'Australia', 'Netherlands', 'Sweden', 'Spain',
#        'Italy', 'Belgium', 'Norway', 'Israel', 'Ireland', 'Austria', 'China',
#        'Taiwan', 'India', 'Korea', 'Brazil', 'Saudi Arabia', 'South Africa',
#        'Mexico', 'Indonesia', 'Turkiye', 'Poland', 'Argentina', 'Russia'],
#       dtype='object')
#
# No data:
# Index([], dtype='object')
#
# Missing first:
#
# Missing last:
#
# Done
