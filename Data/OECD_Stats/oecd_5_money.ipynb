# %%
from oecd_api import get_oecd_data

# %%
indicator = 'KEI' # Key Short-Term Economic Indicators
subject = 'IRSTCI01' # Overnight Interbank Rate
measure = 'ST' # Level, ratio or index
freq = 'M' # Monthly
df = get_oecd_data(indicator, subject, measure, freq, 
                   file_name='Overnight Interbank Rate')
df
# Out:
# https://stats.oecd.org/SDMX-JSON/data/KEI/IRSTCI01.AUS+AUT+BEL+CAN+CHL+COL+CZE+DNK+FIN+FRA+DEU+GRC+HUN+IRL+ISR+ITA+JPN+KOR+MEX+NLD+NZL+NOR+POL+PRT+ESP+SWE+CHE+TUR+GBR+USA+ARG+BRA+CHN+IND+IDN+RUS+SAU+ZAF+EA19.ST.M/all?startTime=1999-01&contentType=csv
# Data coverage:  94.3 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'France',
#        'Switzerland', 'Germany', 'Australia', 'Netherlands', 'Denmark',
#        'Sweden', 'Spain', 'Italy', 'Finland', 'Belgium', 'Norway', 'Israel',
#        'Ireland', 'New Zealand', 'Austria', 'Portugal', 'Eurozone', 'China',
#        'India', 'Korea', 'Brazil', 'South Africa', 'Mexico', 'Indonesia',
#        'Turkiye', 'Poland', 'Chile', 'Greece', 'Hungary', 'Czechia',
#        'Colombia', 'Russia'],
#       dtype='object')
#
# No data:
# Index(['Saudi Arabia', 'Argentina'], dtype='object')
#
# Missing first:
#
# Missing last:
# Sweden 2020-10
# Russia 2022-08
#
# Done
#          United States   Japan  United Kingdom  Canada  France  Switzerland  \
# 1999-01           4.63  0.2253          5.9922  4.9914  3.1370       0.8438
# 1999-02           4.76  0.1763          5.7693  4.9957  3.1180       1.0804
# 1999-03           4.81  0.0409          5.5665  4.9943  2.9252       1.0071
# 1999-04           4.74  0.0314          5.3295  4.7771  2.7091       0.8036
# 1999-05           4.74  0.0300          5.2689  4.5929  2.5510       0.8405
# ...                ...     ...             ...     ...     ...          ...
# 2023-05           5.06 -0.0510          4.3528  4.4926  3.0463       0.9500
# 2023-06           5.08 -0.0660          4.5872  4.6839  3.2046       1.2000
# 2023-07           5.12 -0.0460          4.9302  4.9039  3.4033       1.2000
# 2023-08           5.33 -0.0640          5.1609  4.9942  3.6104       1.2000
# 2023-09           5.33 -0.0540          5.1854  4.9928  3.7125       1.2000
#
#          Germany  Australia  Netherlands  Denmark  ...  Indonesia  Turkiye  \
# 1999-01   3.1370       4.75       3.1370   3.7699  ...      36.43    78.88
# 1999-02   3.1180       4.75       3.1180   3.5736  ...      37.50    77.38
# 1999-03   2.9252       4.75       2.9252   3.4139  ...      37.84    76.32
# 1999-04   2.7091       4.75       2.7091   3.0343  ...      35.19    76.96
# 1999-05   2.5510       4.75       2.5510   2.8990  ...      28.73    76.96
# ...          ...        ...          ...      ...  ...        ...      ...
# 2023-05   3.0463       3.83       3.0463   2.9000  ...       5.56      NaN
# 2023-06   3.2046       4.05       3.2046   3.0900  ...       5.61      NaN
# 2023-07   3.4033       4.10       3.4033   3.2300  ...       5.61      NaN
# 2023-08   3.6104       4.10       3.6104   3.4700  ...       5.62      NaN
# 2023-09   3.7125       4.10       3.7125   3.4800  ...       5.60      NaN
#
#          Poland  Chile   Greece  Hungary  Czechia  Colombia  Argentina  Russia
# 1999-01   15.50  12.94  11.4251  17.9000     9.09     26.98        NaN    60.0
# 1999-02   15.50   6.25  10.1807  14.8000     8.00     23.05        NaN    60.0
# 1999-03   15.50   6.84  10.1474  15.6000     7.70     22.14        NaN    60.0
# 1999-04   15.50  12.81  10.1514  15.3000     7.27     20.72        NaN    60.0
# 1999-05   15.50  11.77  10.4029  14.6000     6.91     18.92        NaN    60.0
# ...         ...    ...      ...      ...      ...       ...        ...     ...
# 2023-05    6.74  11.25   3.0463  17.3508     7.00     13.28        NaN     NaN
# 2023-06    6.71  11.25   3.2046  16.0434     7.00     13.28        NaN     NaN
# 2023-07    6.79  11.25   3.4033  15.4338     7.00     13.26        NaN     NaN
# 2023-08    6.66  10.25   3.6104  14.4524     7.00     13.27        NaN     NaN
# 2023-09    5.95   9.58   3.7125  13.4011     7.00     13.24        NaN     NaN
#
# [297 rows x 39 columns]

# %%
indicator = 'KEI' # Key Short-Term Economic Indicators
subject = 'IR3TIB01' # Short term interest rate
measure = 'ST' # Level, ratio or index
freq = 'M' # Monthly
df = get_oecd_data(indicator, subject, measure, freq, 
                   file_name='Short term interest rate')
df
# Out:
# https://stats.oecd.org/SDMX-JSON/data/KEI/IR3TIB01.AUS+AUT+BEL+CAN+CHL+COL+CZE+DNK+FIN+FRA+DEU+GRC+HUN+IRL+ISR+ITA+JPN+KOR+MEX+NLD+NZL+NOR+POL+PRT+ESP+SWE+CHE+TUR+GBR+USA+ARG+BRA+CHN+IND+IDN+RUS+SAU+ZAF+EA19.ST.M/all?startTime=1999-01&contentType=csv
# Data coverage:  87.7 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'France',
#        'Switzerland', 'Germany', 'Australia', 'Netherlands', 'Denmark',
#        'Sweden', 'Spain', 'Italy', 'Finland', 'Belgium', 'Norway', 'Israel',
#        'Ireland', 'New Zealand', 'Austria', 'Portugal', 'Eurozone', 'China',
#        'India', 'Korea', 'South Africa', 'Mexico', 'Indonesia', 'Turkiye',
#        'Poland', 'Chile', 'Greece', 'Hungary', 'Czechia', 'Colombia',
#        'Russia'],
#       dtype='object')
#
# No data:
# Index(['Brazil', 'Saudi Arabia', 'Argentina'], dtype='object')
#
# Missing first:
# Japan 2002-04
# India 2011-12
#
# Missing last:
# Turkiye 2008-04
# Russia 2022-02
#
# Done
#          United States  Japan  United Kingdom  Canada  France  Switzerland  \
# 1999-01           4.89    NaN          5.9217  5.0045  3.1321          NaN
# 1999-02           4.90    NaN          5.5320  5.0335  3.0934          NaN
# 1999-03           4.91    NaN          5.4229  5.0574  3.0467          NaN
# 1999-04           4.88    NaN          5.3177  4.7167  2.6965          NaN
# 1999-05           4.92    NaN          5.3488  4.6155  2.5790          NaN
# ...                ...    ...             ...     ...     ...          ...
# 2023-05           5.15 -0.019          4.7300  4.7885  3.3664         1.45
# 2023-06           5.22 -0.003          5.0900  5.0218  3.5359         1.45
# 2023-07           5.35 -0.003          5.4900  5.2193  3.6718         1.72
# 2023-08           5.44 -0.003          5.5300  5.2275  3.7803         1.77
# 2023-09           5.49    NaN          5.5200  5.2255  3.8800          NaN
#
#          Germany  Australia  Netherlands  Denmark  ...  Indonesia  Turkiye  \
# 1999-01   3.1321       4.79       3.1321   3.8875  ...      45.50      NaN
# 1999-02   3.0934       4.77       3.0934   3.6150  ...      38.20      NaN
# 1999-03   3.0467       4.81       3.0467   3.4590  ...      34.85      NaN
# 1999-04   2.6965       4.76       2.6965   3.1598  ...      34.09      NaN
# 1999-05   2.5790       4.86       2.5790   3.1085  ...      31.20      NaN
# ...          ...        ...          ...      ...  ...        ...      ...
# 2023-05   3.3664       3.90       3.3664   3.3961  ...       6.76      NaN
# 2023-06   3.5359       4.25       3.5359   3.5624  ...       6.75      NaN
# 2023-07   3.6718       4.30       3.6718   3.7208  ...       6.75      NaN
# 2023-08   3.7803       4.15       3.7803   3.8014  ...       6.74      NaN
# 2023-09   3.8800       4.13       3.8800   3.9102  ...       6.74      NaN
#
#          Poland  Chile   Greece  Hungary  Czechia  Colombia  Argentina  Russia
# 1999-01   12.60  12.75  11.6900  15.8000     8.49     33.23        NaN    43.9
# 1999-02   12.68  10.04  10.6642  15.3000     8.18     30.25        NaN    23.3
# 1999-03   12.84  11.09  10.0505  15.3000     7.58     25.32        NaN    21.6
# 1999-04   12.95  13.59  10.0845  15.4000     7.09     22.08        NaN    20.6
# 1999-05   13.04  11.71   9.9450  14.9000     6.96     19.01        NaN    21.0
# ...         ...    ...      ...      ...      ...       ...        ...     ...
# 2023-05    6.90    NaN   3.3664  14.8287     7.18     12.57        NaN     NaN
# 2023-06    6.90    NaN   3.5359  15.9426     7.15     13.02        NaN     NaN
# 2023-07    6.76    NaN   3.6718  10.3116     7.11     13.58        NaN     NaN
# 2023-08    6.69    NaN   3.7803  13.9097     7.10     13.71        NaN     NaN
# 2023-09    5.99    NaN   3.8800  13.4219     7.09     13.07        NaN     NaN
#
# [297 rows x 39 columns]

# %%
indicator = 'KEI' # Key Short-Term Economic Indicators
subject = 'IRLTLT01' # Long-term interest rate
measure = 'ST' # Level, ratio or index
freq = 'M' # Monthly
df = get_oecd_data(indicator, subject, measure, freq, 
                   file_name='Long term interest rate')
df
# Out:
# https://stats.oecd.org/SDMX-JSON/data/KEI/IRLTLT01.AUS+AUT+BEL+CAN+CHL+COL+CZE+DNK+FIN+FRA+DEU+GRC+HUN+IRL+ISR+ITA+JPN+KOR+MEX+NLD+NZL+NOR+POL+PRT+ESP+SWE+CHE+TUR+GBR+USA+ARG+BRA+CHN+IND+IDN+RUS+SAU+ZAF+EA19.ST.M/all?startTime=1999-01&contentType=csv
# Data coverage:  85.0 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'France',
#        'Switzerland', 'Germany', 'Australia', 'Netherlands', 'Denmark',
#        'Sweden', 'Spain', 'Italy', 'Finland', 'Belgium', 'Norway', 'Israel',
#        'Ireland', 'New Zealand', 'Austria', 'Portugal', 'Eurozone', 'China',
#        'India', 'Korea', 'Brazil', 'South Africa', 'Mexico', 'Indonesia',
#        'Poland', 'Chile', 'Greece', 'Hungary', 'Czechia', 'Colombia',
#        'Russia'],
#       dtype='object')
#
# No data:
# Index(['Saudi Arabia', 'Turkiye', 'Argentina'], dtype='object')
#
# Missing first:
# China 2014-01
# India 2011-12
# Korea 2000-10
# Mexico 2001-07
# Indonesia 2012-01
# Poland 2001-01
# Chile 2004-07
# Czechia 2000-04
# Colombia 2003-01
#
# Missing last:
# Russia 2018-06
#
# Done
#          United States  Japan  United Kingdom  Canada  France  Switzerland  \
# 1999-01           4.72  1.910          4.2868  4.9465  3.7700        2.555
# 1999-02           5.00  2.117          4.4319  5.1240  3.9290        2.550
# 1999-03           5.23  1.816          4.6554  5.2204  4.1335        2.604
# 1999-04           5.18  1.563          4.5920  5.0295  3.9762        2.534
# 1999-05           5.54  1.334          4.9068  5.3595  4.1600        2.720
# ...                ...    ...             ...     ...     ...          ...
# 2023-05           3.57  0.430          3.9621  3.0455  2.9400        0.850
# 2023-06           3.75  0.395          4.3659  3.3382  2.9300        0.970
# 2023-07           3.90  0.595          4.4372  3.4520  3.0400        0.980
# 2023-08           4.17  0.640          4.5298  3.6541  3.1100        0.950
# 2023-09           4.38  0.765          4.4199  3.8160  3.2300        1.090
#
#          Germany  Australia  Netherlands  Denmark  ...  Indonesia  Turkiye  \
# 1999-01   3.7020     5.1279        3.801    4.035  ...        NaN      NaN
# 1999-02   3.8490     5.3000        3.932    4.188  ...        NaN      NaN
# 1999-03   4.0378     5.5265        4.139    4.432  ...        NaN      NaN
# 1999-04   3.8500     5.3575        3.995    4.217  ...        NaN      NaN
# 1999-05   4.0121     5.8757        4.193    4.461  ...        NaN      NaN
# ...          ...        ...          ...      ...  ...        ...      ...
# 2023-05   2.3423     3.5000        2.728    2.539  ...       6.36      NaN
# 2023-06   2.3764     3.9200        2.750    2.571  ...       6.22      NaN
# 2023-07   2.4567     4.0300        2.840    2.695  ...       6.33      NaN
# 2023-08   2.5457     4.1300        2.917    2.768  ...       6.36      NaN
# 2023-09   2.6600     4.2100          NaN      NaN  ...        NaN      NaN
#
#          Poland   Chile  Greece  Hungary  Czechia  Colombia  Argentina  Russia
# 1999-01     NaN     NaN    6.30      NaN      NaN       NaN        NaN   96.34
# 1999-02     NaN     NaN    6.00     9.27      NaN       NaN        NaN   99.47
# 1999-03     NaN     NaN    6.00     9.72      NaN       NaN        NaN   98.67
# 1999-04     NaN     NaN    5.90     9.73      NaN       NaN        NaN  110.55
# 1999-05     NaN     NaN    5.80     9.72      NaN       NaN        NaN   96.75
# ...         ...     ...     ...      ...      ...       ...        ...     ...
# 2023-05    5.93  5.5486    3.98     7.78     4.50     11.11        NaN     NaN
# 2023-06    5.91  5.3055    3.70     7.20     4.35     10.15        NaN     NaN
# 2023-07    5.56  5.3305    3.85     7.10     4.15     10.22        NaN     NaN
# 2023-08    5.59  5.6347    3.90     7.40     4.26     10.70        NaN     NaN
# 2023-09    5.68  5.9392    4.05     7.08      NaN     11.87        NaN     NaN
#
# [297 rows x 39 columns]

# %%
indicator = 'MEI' # Main Economic Indicators
subject = 'MANMM101' # Narrow Money - M1 and components
measure = 'ST' # National Currency
freq = 'M' # Monthly

df = get_oecd_data(indicator, subject, measure, freq, 
                   countries_before_subject=True,
                   file_name='Narrow Money M1')
df
# Out:
# https://stats.oecd.org/SDMX-JSON/data/MEI/AUS+AUT+BEL+CAN+CHL+COL+CZE+DNK+FIN+FRA+DEU+GRC+HUN+IRL+ISR+ITA+JPN+KOR+MEX+NLD+NZL+NOR+POL+PRT+ESP+SWE+CHE+TUR+GBR+USA+ARG+BRA+CHN+IND+IDN+RUS+SAU+ZAF+EA19.MANMM101.ST.M/all?startTime=1999-01&contentType=csv
# Data coverage:  63.5 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'Switzerland',
#        'Australia', 'Denmark', 'Sweden', 'Norway', 'Israel', 'New Zealand',
#        'Eurozone', 'China', 'India', 'Korea', 'Brazil', 'South Africa',
#        'Mexico', 'Indonesia', 'Turkiye', 'Poland', 'Chile', 'Hungary',
#        'Czechia', 'Russia'],
#       dtype='object')
#
# No data:
# Index(['France', 'Germany', 'Netherlands', 'Spain', 'Italy', 'Finland',
#        'Belgium', 'Ireland', 'Austria', 'Portugal', 'Saudi Arabia', 'Greece',
#        'Colombia', 'Argentina'],
#       dtype='object')
#
# Missing first:
#
# Missing last:
# New Zealand 2018-12
#
# Done
#          United States         Japan  United Kingdom    Canada  France  \
# 1999-01         1103.9  2.503207e+06        359951.0   203.111     NaN
# 1999-02         1085.2  2.462410e+06        362493.0   200.414     NaN
# 1999-03         1097.5  2.577053e+06        374161.0   199.059     NaN
# 1999-04         1113.6  2.632567e+06        369023.0   203.614     NaN
# 1999-05         1096.4  2.670634e+06        372564.0   207.212     NaN
# ...                ...           ...             ...       ...     ...
# 2023-04        18746.9  1.069616e+07       2317997.0  1505.770     NaN
# 2023-05        18501.5  1.073424e+07       2314472.0  1503.487     NaN
# 2023-06        18449.4  1.072017e+07       2304395.0  1505.754     NaN
# 2023-07        18354.9  1.071008e+07       2283949.0  1510.883     NaN
# 2023-08        18248.5           NaN       2254323.0       NaN     NaN
#
#          Switzerland  Germany  Australia  Netherlands    Denmark  ...  \
# 1999-01     201287.0      NaN      115.0          NaN   381467.0  ...
# 1999-02     206120.0      NaN      114.5          NaN   375890.0  ...
# 1999-03     203007.0      NaN      114.0          NaN   373044.0  ...
# 1999-04     209720.0      NaN      115.5          NaN   397591.0  ...
# 1999-05     210485.0      NaN      115.8          NaN   404926.0  ...
# ...              ...      ...        ...          ...        ...  ...
# 2023-04     698014.0      NaN     1625.0          NaN  1565234.7  ...
# 2023-05     683123.0      NaN     1620.7          NaN  1546405.3  ...
# 2023-06     668225.0      NaN     1621.0          NaN  1530061.1  ...
# 2023-07     651319.0      NaN     1617.9          NaN  1544155.3  ...
# 2023-08     641876.0      NaN     1613.8          NaN  1551964.7  ...
#
#          Indonesia       Turkiye     Poland       Chile  Greece     Hungary  \
# 1999-01    101.953  3.511547e+03    88635.8   2920.0700     NaN   1822.5840
# 1999-02    103.458  3.516057e+03    91943.2   2945.4500     NaN   1845.4674
# 1999-03    105.705  4.545328e+03    95283.3   2903.5400     NaN   1884.6005
# 1999-04    100.708  3.944113e+03    93989.0   2882.3000     NaN   1881.2429
# 1999-05    103.301  3.923985e+03    97092.0   2932.1500     NaN   1989.0889
# ...            ...           ...        ...         ...     ...         ...
# 2023-04   4673.100  3.676969e+06  1548800.0  55688.3942     NaN  31201.7796
# 2023-05   4623.100  3.523187e+06  1555670.0  55657.7070     NaN  30966.0069
# 2023-06   4682.800  4.180491e+06  1554380.0  55363.0455     NaN  30465.0099
# 2023-07   4648.200  4.390129e+06  1571610.0  54720.3053     NaN  30617.4685
# 2023-08   4609.400  4.545571e+06        NaN  54385.9705     NaN  30469.4057
#
#            Czechia  Colombia  Argentina  Russia
# 1999-01   475.1890       NaN        NaN   177.9
# 1999-02   481.8679       NaN        NaN   180.6
# 1999-03   482.1152       NaN        NaN   174.0
# 1999-04   488.7941       NaN        NaN   195.1
# 1999-05   499.3071       NaN        NaN   205.1
# ...            ...       ...        ...     ...
# 2023-04  4823.1234       NaN        NaN     NaN
# 2023-05  4913.5924       NaN        NaN     NaN
# 2023-06  4907.5512       NaN        NaN     NaN
# 2023-07  4947.9000       NaN        NaN     NaN
# 2023-08  4960.2000       NaN        NaN     NaN
#
# [296 rows x 39 columns]

# %%
indicator = 'MEI' # Main Economic Indicators
subject = 'MABMM301' # Broad Money - M3 and components
measure = 'ST' # National Currency
freq = 'M' # Monthly

df = get_oecd_data(indicator, subject, measure, freq, 
                   countries_before_subject=True,
                   file_name='Broad Money M3')
df
# Out:
# https://stats.oecd.org/SDMX-JSON/data/MEI/AUS+AUT+BEL+CAN+CHL+COL+CZE+DNK+FIN+FRA+DEU+GRC+HUN+IRL+ISR+ITA+JPN+KOR+MEX+NLD+NZL+NOR+POL+PRT+ESP+SWE+CHE+TUR+GBR+USA+ARG+BRA+CHN+IND+IDN+RUS+SAU+ZAF+EA19.MABMM301.ST.M/all?startTime=1999-01&contentType=csv
# Data coverage:  63.5 %
#
# Available countries:
# Index(['United States', 'Japan', 'United Kingdom', 'Canada', 'Switzerland',
#        'Australia', 'Denmark', 'Sweden', 'Norway', 'Israel', 'New Zealand',
#        'Eurozone', 'China', 'India', 'Korea', 'Brazil', 'South Africa',
#        'Mexico', 'Indonesia', 'Turkiye', 'Poland', 'Chile', 'Hungary',
#        'Czechia', 'Russia'],
#       dtype='object')
#
# No data:
# Index(['France', 'Germany', 'Netherlands', 'Spain', 'Italy', 'Finland',
#        'Belgium', 'Ireland', 'Austria', 'Portugal', 'Saudi Arabia', 'Greece',
#        'Colombia', 'Argentina'],
#       dtype='object')
#
# Missing first:
#
# Missing last:
# Czechia 2018-12
#
# Done
#          United States         Japan  United Kingdom    Canada  France  \
# 1999-01         4409.5  9.415504e+06        817074.0   597.640     NaN
# 1999-02         4418.7  9.364157e+06        824741.0   595.777     NaN
# 1999-03         4455.6  9.431088e+06        832631.0   598.793     NaN
# 1999-04         4501.4  9.481738e+06        835921.0   606.502     NaN
# 1999-05         4464.1  9.506468e+06        844372.0   608.041     NaN
# ...                ...           ...             ...       ...     ...
# 2023-04        20865.9  1.587349e+07       3544161.0  3460.010     NaN
# 2023-05        20749.1  1.590454e+07       3559219.0  3461.115     NaN
# 2023-06        20802.6  1.594298e+07       3563149.0  3470.763     NaN
# 2023-07        20786.2  1.594625e+07       3541354.0  3498.614     NaN
# 2023-08        20760.3           NaN       3549836.0       NaN     NaN
#
#          Switzerland  Germany  Australia  Netherlands    Denmark  ...  \
# 1999-01     477485.0      NaN      386.1          NaN   538381.0  ...
# 1999-02     483479.0      NaN      387.4          NaN   525330.0  ...
# 1999-03     481796.0      NaN      388.7          NaN   518872.0  ...
# 1999-04     484440.0      NaN      392.8          NaN   550505.0  ...
# 1999-05     484532.0      NaN      397.9          NaN   547787.0  ...
# ...              ...      ...        ...          ...        ...  ...
# 2023-04    1153875.0      NaN     2868.5          NaN  1889329.4  ...
# 2023-05    1142752.0      NaN     2874.8          NaN  1878493.6  ...
# 2023-06    1133624.0      NaN     2871.7          NaN  1864208.0  ...
# 2023-07    1135752.0      NaN     2896.6          NaN  1880333.5  ...
# 2023-08    1132314.0      NaN     2903.5          NaN  1916533.7  ...
#
#          Indonesia       Turkiye     Poland        Chile  Greece     Hungary  \
# 1999-01    596.541  2.320021e+04   226342.7   31230.5800     NaN   4523.1799
# 1999-02    602.666  2.420893e+04   233423.8   31216.2700     NaN   4592.5246
# 1999-03    603.325  2.597040e+04   236748.5   31144.8200     NaN   4581.5276
# 1999-04    613.140  2.735291e+04   236784.4   31502.1300     NaN   4570.7872
# 1999-05    628.260  2.909660e+04   240024.5   32249.6600     NaN   4663.6148
# ...            ...           ...        ...          ...     ...         ...
# 2023-04   8352.300  9.510649e+06  2147520.0  318732.0483     NaN  40982.4906
# 2023-05   8332.300  9.409262e+06  2157900.0  322092.0552     NaN  40797.6986
# 2023-06   8373.000  1.083449e+07  2157330.0  322524.3287     NaN  39999.2729
# 2023-07   8349.500  1.177296e+07  2173200.0  323314.8085     NaN  40622.9861
# 2023-08   8363.200  1.234337e+07        NaN  326980.5716     NaN  40880.6467
#
#          Czechia  Colombia  Argentina  Russia
# 1999-01   1229.7       NaN        NaN   644.0
# 1999-02   1247.4       NaN        NaN   665.8
# 1999-03   1247.9       NaN        NaN   683.7
# 1999-04   1261.5       NaN        NaN   726.8
# 1999-05   1271.9       NaN        NaN   765.6
# ...          ...       ...        ...     ...
# 2023-04      NaN       NaN        NaN     NaN
# 2023-05      NaN       NaN        NaN     NaN
# 2023-06      NaN       NaN        NaN     NaN
# 2023-07      NaN       NaN        NaN     NaN
# 2023-08      NaN       NaN        NaN     NaN
#
# [296 rows x 39 columns]
